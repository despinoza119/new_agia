# %% [markdown]
# **Acceso a la data de precios**

# %%
#Importamos las librerias a utilizar
import requests
import pandas as pd
from pandas import json_normalize
import time

#Definimos el endpoint
url = 'https://api.abastores.com/api/v2/marketdata/dataprice/'

#Parametros de paginacion
page_size = 1000
pages = 10
all_data = []

for page in range(1,pages+1):
    print(page)
    params = {'page': page, 'page_size': page_size}
    headers = {
                'accept': 'application/json',
                'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzA2MjcyNTcxLCJqdGkiOiIxMDNmNWQ0MzAxMGU0MWNjOTcyOGNhMjA0ZWU2ZDQ3YSIsInVzZXJfaWQiOjQzODV9.kloRA-VamXlUpO6D98GDfxPXVssTV2Dt_JP4i8WeqFM'
              }
    time.sleep(2)
    response = requests.get(url,params=params, headers=headers)
    if response.status_code == 200:
        json_data = response.json()
        results = json_data.get('results', [])
        df = pd.DataFrame(results)
    
        df_expanded = pd.concat([
        df.drop(columns=['product', 'province', 'data_source', 'last_deviation']),
        json_normalize(df['product']).add_prefix('product_'),
        json_normalize(df['province']).add_prefix('province_'),
        json_normalize(df['data_source']).add_prefix('data_source_'),
        json_normalize(df['last_deviation']).add_prefix('last_deviation_')
        ], axis=1)
    
        all_data.append(df_expanded)
    else:
        print(f'No se pudo recopilar el {page}')

final_df = pd.concat(all_data, ignore_index=True)
# Out:
# 1
# 2
# 3
# 4
# No se pudo recopilar el 4
# 5
# No se pudo recopilar el 5
# 6
# No se pudo recopilar el 6
# 7
# No se pudo recopilar el 7
# 8
# No se pudo recopilar el 8
# 9
# No se pudo recopilar el 9
# 10
# No se pudo recopilar el 10

# %%
final_df.columns
# Out:
# Index(['id', 'date', 'price', 'quantity', 'region', 'product_id',
#        'product_meta_product.id', 'product_meta_product.name',
#        'product_meta_product.icon', 'product_family.id', 'product_family.name',
#        'product_variety.id', 'product_variety.name', 'province_id',
#        'province_name', 'data_source_id', 'data_source_name',
#        'data_source_link', 'data_source_kind', 'last_deviation_date',
#        'last_deviation_deviation'],
#       dtype='object')

# %%
final_df.groupby(['province_name', 'product_meta_product.name']).count()
# Out:
#                                          id  date  price  quantity  region  \
# province_name product_meta_product.name
# Albacete      Avena                       2     2      2         0       0
#               Cebada                      3     3      3         0       0
#               Centeno                     1     1      1         0       0
#               Maíz                        2     2      2         0       0
#               Trigo                       5     5      5         0       0
#               Triticale                   1     1      1         0       0
# Barcelona     Cebada                      2     2      2         0       0
#               Maíz                        2     2      2         0       0
#               Pipa                        1     1      1         0       0
#               Trigo                       1     1      1         0       0
# Burgos        Trigo                       1     1      1         0       0
# ...

# %%
import requests
import pandas as pd
from pandas import json_normalize

url = 'https://api.abastores.com/api/v2/marketdata/dataprice/?page=3&page_size=100'
page_size = 1000
page = 2
data_list = []
bearer_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzA2MjcyNTcxLCJqdGkiOiIxMDNmNWQ0MzAxMGU0MWNjOTcyOGNhMjA0ZWU2ZDQ3YSIsInVzZXJfaWQiOjQzODV9.kloRA-VamXlUpO6D98GDfxPXVssTV2Dt_JP4i8WeqFM'

while True:
    params = {'page': page, 'page_size': page_size}
    headers = {
        'accept': 'application/json',
        'Authorization': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzA2MjcyNTcxLCJqdGkiOiIxMDNmNWQ0MzAxMGU0MWNjOTcyOGNhMjA0ZWU2ZDQ3YSIsInVzZXJfaWQiOjQzODV9.kloRA-VamXlUpO6D98GDfxPXVssTV2Dt_JP4i8WeqFM'
    }
    
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        results = json_data.get('results', [])

        if not results:
            break

        data_list.extend(results)
        page += 1
    else:
        print(f"Error: {response.status_code}")
        break

df = pd.DataFrame(data_list)

df_normalized = pd.json_normalize(df['results'])

df.to_csv('api_data.csv', index=False)

# %% [markdown]
# **Solucion 1**
# - Endpoint: 'https://api.abastores.com/api/v2/marketdata/dataprice/'
# - Solution: Intentar conectarse y recopilar data por pagina

# %%
import requests
import pandas as pd
from pandas import json_normalize

url = 'https://api.abastores.com/api/v2/marketdata/dataprice/'
page_size = 1000
page = 2
data_list = []

while True:
    params = {'page': page, 'page_size': page_size}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        json_data = response.json()
        results = json_data.get('results', [])

        if not results:
            break

        data_list.extend(results)
        page += 1
    else:
        print(f"Error: {response.status_code}")
        break

df = pd.DataFrame(data_list)

df_normalized = pd.json_normalize(df['results'])

df.to_csv('api_data.csv', index=False)
# Out:
# Error: 404
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 29
#      25         break
#      27 df = pd.DataFrame(data_list)
# ---> 29 df_normalized = pd.json_normalize(df['results'])
#      31 df.to_csv('api_data.csv', index=False)
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
# ...

# %% [markdown]
# **Solucion 2**
# - Endpoint: 'https://api.abastores.com/api/v2/marketdata/dataprice/?page=1'
# - Solution: Intentar conectarse y recopilar data por pagina cambiando el query en el endpoint

# %%
import requests
import pandas as pd
from pandas import json_normalize

url = 'https://api.abastores.com/api/v2/marketdata/dataprice/?page=1'
page_size = 1000
page_number = 1
data_list = []

response = requests.get(url)

if response.status_code == 200:
    json_data = response.json()
    results = json_data.get('results', [])

    if not results:
          # No more data, exit the loop

    data_list.extend(results)
    page_number += 1
else:
    print(f"Error: {response.status_code}")

# Convert the list of data into a DataFrame
df = pd.DataFrame(data_list)

# Optionally, normalize JSON data within the DataFrame
df_normalized = pd.json_normalize(df['results'])

# Save the DataFrame to a CSV file
df.to_csv('api_data.csv', index=False)
# Out:
# Error: 200
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[151], line 26
#      22     print(f"Error: {response.status_code}")
#      24 df = pd.DataFrame(data_list)
# ---> 26 df_normalized = pd.json_normalize(df['results'])
#      28 df.to_csv('api_data.csv', index=False)
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# ...

# %% [markdown]
# **Exploracion del API**

# %%
url = 'https://api.abastores.com/api/v2/marketdata/dataprice/?page=1'

response = requests.get(url)

if response.status_code == 200:
    print(response.json())
else:
    print(f"Error: {response.status_code}")
json_data = response.json()
df = pd.DataFrame(json_data)
df.to_csv('api_data.csv', index=False)
df_1=pd.DataFrame(json_normalize(df['results']))
# Out:
# {'count': 6, 'next': None, 'previous': None, 'results': [{'id': 178992, 'product': {'id': 20461, 'meta_product': {'id': 5, 'name': 'Cebada', 'icon': 'a-barley'}, 'family': {'id': 1, 'name': 'Cereales'}, 'variety': {'id': 1, 'name': 'Común'}}, 'province': {'id': 15, 'name': 'Valladolid'}, 'data_source': {'id': 31, 'name': 'Abastores', 'link': 'https://www.abastores.com/', 'kind': 'ABASTORES'}, 'last_deviation': {'date': '2024-01-24T15:35:00Z', 'deviation': 0.0}, 'date': '2024-01-24T16:35:00+01:00', 'price': 208.0, 'quantity': None, 'region': None}, {'id': 178991, 'product': {'id': 20461, 'meta_product': {'id': 5, 'name': 'Cebada', 'icon': 'a-barley'}, 'family': {'id': 1, 'name': 'Cereales'}, 'variety': {'id': 1, 'name': 'Común'}}, 'province': {'id': 56, 'name': 'Zaragoza'}, 'data_source': {'id': 31, 'name': 'Abastores', 'link': 'https://www.abastores.com/', 'kind': 'ABASTORES'}, 'last_deviation': {'date': '2024-01-24T15:35:00Z', 'deviation': 0.0}, 'date': '2024-01-24T16:35:00+01:00', 
# ...

# %%
url = 'https://api.abastores.com/api/v2/marketdata/dataprice/?page=1'

response = requests.get(url)

if response.status_code == 200:
    print(response.json())
else:
    print(f"Error: {response.status_code}")
json_data = response.json()
df = pd.DataFrame(json_data)
df.to_csv('api_data.csv', index=False)
df_1=pd.DataFrame(json_normalize(df['results']))
# Out:
# {'count': 6, 'next': None, 'previous': None, 'results': [{'id': 178992, 'product': {'id': 20461, 'meta_product': {'id': 5, 'name': 'Cebada', 'icon': 'a-barley'}, 'family': {'id': 1, 'name': 'Cereales'}, 'variety': {'id': 1, 'name': 'Común'}}, 'province': {'id': 15, 'name': 'Valladolid'}, 'data_source': {'id': 31, 'name': 'Abastores', 'link': 'https://www.abastores.com/', 'kind': 'ABASTORES'}, 'last_deviation': {'date': '2024-01-24T15:35:00Z', 'deviation': 0.0}, 'date': '2024-01-24T16:35:00+01:00', 'price': 208.0, 'quantity': None, 'region': None}, {'id': 178991, 'product': {'id': 20461, 'meta_product': {'id': 5, 'name': 'Cebada', 'icon': 'a-barley'}, 'family': {'id': 1, 'name': 'Cereales'}, 'variety': {'id': 1, 'name': 'Común'}}, 'province': {'id': 56, 'name': 'Zaragoza'}, 'data_source': {'id': 31, 'name': 'Abastores', 'link': 'https://www.abastores.com/', 'kind': 'ABASTORES'}, 'last_deviation': {'date': '2024-01-24T15:35:00Z', 'deviation': 0.0}, 'date': '2024-01-24T16:35:00+01:00', 
# ...

# %%
df_1
# Out:
#        id                       date  price quantity region  product.id  \
# 0  178992  2024-01-24T16:35:00+01:00  208.0     None   None       20461
# 1  178991  2024-01-24T16:35:00+01:00  198.5     None   None       20461
# 2  178990  2024-01-24T16:35:00+01:00  212.0     None   None       20461
# 3  178989  2024-01-24T16:35:00+01:00  211.0     None   None       20461
# 4  178988  2024-01-24T16:35:00+01:00  196.0     None   None       20461
# 5  178987  2024-01-24T16:35:00+01:00  209.0     None   None       20461
#
#    product.meta_product.id product.meta_product.name  \
# 0                        5                    Cebada
# 1                        5                    Cebada
# 2                        5                    Cebada
# 3                        5                    Cebada
# 4                        5                    Cebada
# 5                        5                    Cebada
#
#   product.meta_product.icon  product.family.id  ... product.variety.id  \
# ...

# %%
url = 'https://api.abastores.com/api/v1/marketdata/data-prices/?data_source_kind=ABASTORES&limit=1000000'
headers = {'accept': 'application/json'}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    print(response.json())
else:
    print(f"Error: {response.status_code}")

json_data = response.json()
df = pd.DataFrame(json_data)
df.to_csv('api_data.csv', index=False)
df_1=pd.DataFrame(json_normalize(df['results']))
# Out:
# {'count': 23, 'next': None, 'previous': None, 'results': [{'id': 2, 'product': {'id': 1, 'meta_product': {'id': 284, 'name': 'Trigo', 'iva': 4, 'icon': 'a-wheat', 'logo': 'https://api.abastores.com/media/logos/product/Trigo.png'}, 'family': {'id': 1, 'name': 'Cereales'}, 'variety': {'id': 15557, 'name': 'Blando'}, 'other_variety': None, 'other_family': None}, 'province': {'id': 6, 'product_count': 1, 'name': 'Cáceres'}, 'region': {'id': 3, 'name': 'Sierra de Montánchez y Tamuja'}, 'data_source': {'id': 31, 'name': 'Abastores', 'link': 'https://www.abastores.com/', 'kind': 'ABASTORES'}, 'last_deviation': None, 'date': '2022-02-10T01:00:00+01:00', 'price': 301.0, 'quantity': 25000.0}, {'id': 3, 'product': {'id': 21816, 'meta_product': {'id': 4, 'name': 'Maíz', 'iva': 4, 'icon': 'a-corn', 'logo': 'https://api.abastores.com/media/logos/product/Maiz.png'}, 'family': {'id': 1, 'name': 'Cereales'}, 'variety': {'id': 15541, 'name': 'Importación'}, 'other_variety': '', 'other_family': ''}, 'p
# ...

# %%
df_2=pd.concat([df,df_1],axis=1)

# %%
print(len(df_2))
df_2.columns
# Out:
# 23
# Index(['count', 'next', 'previous', 'results', 'id', 'last_deviation', 'date',
#        'price', 'quantity', 'product.id', 'product.meta_product.id',
#        'product.meta_product.name', 'product.meta_product.iva',
#        'product.meta_product.icon', 'product.meta_product.logo',
#        'product.family.id', 'product.family.name', 'product.variety.id',
#        'product.variety.name', 'product.other_variety', 'product.other_family',
#        'province.id', 'province.product_count', 'province.name', 'region.id',
#        'region.name', 'data_source.id', 'data_source.name', 'data_source.link',
#        'data_source.kind', 'region', 'last_deviation.date',
#        'last_deviation.deviation'],
#       dtype='object')

# %%
df_2
# Out:
#     count  next previous                                            results  \
# 0      23  None     None  {'id': 2, 'product': {'id': 1, 'meta_product':...
# 1      23  None     None  {'id': 3, 'product': {'id': 21816, 'meta_produ...
# 2      23  None     None  {'id': 4, 'product': {'id': 21737, 'meta_produ...
# 3      23  None     None  {'id': 5, 'product': {'id': 1, 'meta_product':...
# 4      23  None     None  {'id': 7, 'product': {'id': 21758, 'meta_produ...
# 5      23  None     None  {'id': 8, 'product': {'id': 21816, 'meta_produ...
# 6      23  None     None  {'id': 10, 'product': {'id': 547, 'meta_produc...
# 7      23  None     None  {'id': 11, 'product': {'id': 20461, 'meta_prod...
# 8      23  None     None  {'id': 12, 'product': {'id': 20461, 'meta_prod...
# 9      23  None     None  {'id': 82, 'product': {'id': 21758, 'meta_prod...
# 10     23  None     None  {'id': 178953, 'product': {'id': 1, 'meta_prod...
# ...

# %%
df_2[['province.id','province.name']].sort_values('province.id').drop_duplicates()
# Out:
#     province.id province.name
# 7             2        Toledo
# 3             3      Albacete
# 19            5   Ciudad Real
# 0             6       Cáceres
# 1             7        Huelva
# 2             8       Navarra
# 4             9       Córdoba
# 5            10        Murcia
# 12           11      Palencia
# 13           12        Burgos
# 16           13        Cuenca
# 15           14          León
# 21           15    Valladolid
# 17           45        Lleida
# 10           56      Zaragoza

# %%
df_2[['product.id','product.meta_product.id','product.meta_product.name']].sort_values('product.id').drop_duplicates()
# Out:
#     product.id  product.meta_product.id product.meta_product.name
# 0            1                      284                     Trigo
# 6          547                        6                   Centeno
# 22       20461                        5                    Cebada
# 2        21737                        8                     Avena
# 9        21758                        4                      Maíz
# 5        21816                        4                      Maíz

# %%
df_2[['product.id','product.name']].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 df_2[['product.id','product.name']].value_counts()
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
# ...

# %%
url = 'https://api.abastores.com/api/v1/marketdata/data-prices/'
headers = {'accept': 'application/json'}

response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Process the API response (response.text, response.json(), etc.)
    print(response.json())
else:
    # Handle errors
    print(f"Error: {response.status_code}")

json_data = response.json()
df = pd.DataFrame(json_data)
df.to_csv('api_data.csv', index=False)
df_1=pd.DataFrame(json_normalize(df['results']))
# Out:
# Error: 502
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/envs/DataScienceFoundations/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
df

# %%
df_1

# %%
import requests
import pandas as pd

url = 'https://api.abastores.com/api/v1/marketdata/data-prices/history/?limit=10000&province_id=16'
headers = {'accept': 'application/json'}

response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Process the API response and convert JSON data to a DataFrame
    json_data = response.json()

    # Assuming the JSON data is a list of dictionaries, you can directly convert it to a DataFrame
    df = pd.DataFrame(json_data)

    # Print the DataFrame
    print(df)

    # Optionally, you can save the DataFrame to a CSV file
    df.to_csv('api_data.csv', index=False)
else:
    # Handle errors
    print(f"Error: {response.status_code}")
# Out:
# Empty DataFrame
# Columns: [count, next, previous, results]
# Index: []

# %%
df
# Out:
#       count                                               next previous  \
# 0     34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 1     34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 2     34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 3     34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 4     34826  https://api.abastores.com/api/v1/marketdata/da...     None
# ...     ...                                                ...      ...
# 9995  34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 9996  34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 9997  34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 9998  34826  https://api.abastores.com/api/v1/marketdata/da...     None
# 9999  34826  https://api.abastores.com/api/v1/marketdata/da...     None
#
#                                                 results
# ...

# %%
from pandas import json_normalize
df_1=pd.DataFrame(json_normalize(df['results']))

# %%
df_1
# Out:
#                            date   price
# 0     2024-01-23T18:15:00+01:00  217.25
# 1     2024-01-23T18:15:00+01:00  186.00
# 2     2024-01-23T18:10:00+01:00  206.50
# 3     2024-01-23T18:05:00+01:00  213.50
# 4     2024-01-23T18:05:00+01:00  207.00
# ...                         ...     ...
# 9995  2019-02-13T01:00:00+01:00  160.00
# 9996  2019-02-13T01:00:00+01:00  183.00
# 9997  2019-02-13T00:00:00+01:00  166.00
# 9998  2019-02-11T01:00:00+01:00  176.69
# 9999  2019-02-11T01:00:00+01:00  213.75
#
# [10000 rows x 2 columns]

# %%
df_1['id'].unique()
# Out:
# array([     2,      3,      4,      5,      7,      8,     10,     11,
#            12,     82,  66918,  66919,  66920,  66921,  66922,  66923,
#         66924, 103586, 105024, 120839, 120841, 120842, 120843, 120848,
#        120849, 163617, 163621, 165403, 165570, 165590, 165591, 170999,
#        171000, 171001, 171002, 171003, 171004, 171005, 171006, 171007,
#        171008, 171009, 171040, 171271, 171272, 171288, 171289, 171292,
#        171293, 171558, 171559, 171560, 171562, 171568, 171570, 171609,
#        171610, 171611, 171612, 171613, 171614, 171615, 171616, 171634,
#        171635, 171636, 171637, 171638, 171681, 171721, 171735, 171762,
#        171777, 171833, 171860, 171991, 172091, 172092, 173569, 173714,
#        173828, 174564, 174665, 175150, 175151, 175819, 175951, 175952,
#        176229, 176331, 176332, 176464, 176510, 176570, 176619, 176643,
#        176646, 176650, 176651, 176952, 177018, 177091, 177402, 177406,
# ...
